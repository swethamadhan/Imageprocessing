# %%
#load the image

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# read image
img = cv2.imread("/content/Dog.jpg")

# %%
# convert image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
# detect edges using Canny edge detection
edges = cv2.Canny(gray, 50, 150)

# %%
# display original image
cv2_imshow( img)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1400 at 0x7FF928A5F7C0>

# %%
# display edges
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=1000x1400 at 0x7FF937A23D60>

# %%
# display Gaussian filtered image
gaussian = cv2.GaussianBlur(img,(5,5),0)
cv2_imshow(gaussian)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1400 at 0x7FF9289825B0>

# %%
#perform median filtering

# %%
img2 = cv2.imread("/content/ocv.png")

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=428x378 at 0x7FF9289F5D60>

# %%
# display median filtered 
median = cv2.medianBlur(img2,5)
cv2_imshow(median)
# Out:
# <PIL.Image.Image image mode=RGB size=428x378 at 0x7FF9289F5D60>
